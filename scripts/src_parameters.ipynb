# %%
# src_array = ["bookings", "airports", "customers","flights"]
# this is one of the way to pass the value as input in src. but we will use dict. to pass the values. more professional

# %%
src_array = [
               {"src": "bookings"},
                {"src": "airports"},
                {"src": "customers"},
                {"src": "flights"}
            ]

# %%
dbutils.jobs.taskValues.set(key = "output_key", value = src_array)

# %%
# now create a pipeline to ingest the values as input to src parameters.
