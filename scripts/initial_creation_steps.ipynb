# %%
# %sql
CREATE VOLUME workspace.raw.rawvolumne

# %%
dbutils.fs.mkdirs("/Volumes/workspace/raw/rawvolumne/rawdata")

# %%
#dbutils.fs.mkdirs("/Volumes/workspace/raw/rawvolumne/rawdata/bookings")
# dbutils.fs.mkdirs("/Volumes/workspace/raw/rawvolumne/rawdata/airports")
# dbutils.fs.mkdirs("/Volumes/workspace/raw/rawvolumne/rawdata/customers")
dbutils.fs.mkdirs("/Volumes/workspace/raw/rawvolumne/rawdata/flights")

# %%
# %sql
-- CREATE SCHEMA workspace.bronze
-- CREATE SCHEMA workspace.silver
CREATE SCHEMA workspace.gold

# %%
# %sql
-- CREATE VOLUME workspace.bronze.bronzevolume
-- CREATE VOLUME workspace.silver.silvervolume
CREATE VOLUME workspace.gold.goldvolume
